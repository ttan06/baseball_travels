# %%
import pandas as pd

df= pd.read_csv('/content/Consumer_Airfare_Report__Table_1_-_Top_1_000_Contiguous_State_City-Pair_Markets-2.csv')
print(len(df))
cities = df[['city1', 'city2','fare']]
display(cities)
# Initialize an empty DataFrame to hold the matrix
# cost_matrix = pd.DataFrame(index=cities, columns=cities)

# # Populate the matrix with the fares
# for i, row in df.iterrows():|
#     cost_matrix.at[row['city1'], row['city2']] = row['fare']
#     # Assuming the fare is the same in both directions
#     cost_matrix.at[row['city2'], row['city1']] = row['fare']

# # Replace NaN with 0 or some other placeholder for no flight available
# cost_matrix.fillna(0, inplace=True)

# # Display the cost matrix
# print(cost_matrix)
# Out:
# 3002
#                                city1                                  city2  \
# 0     Allentown/Bethlehem/Easton, PA          Tampa, FL (Metropolitan Area)
# 1     Allentown/Bethlehem/Easton, PA                            Sanford, FL
# 2                    Albuquerque, NM                  Dallas/Fort Worth, TX
# 3                    Albuquerque, NM                             Denver, CO
# 4                    Albuquerque, NM                             Austin, TX
# ...                              ...                                    ...
# 2997                    Syracuse, NY          Tampa, FL (Metropolitan Area)
# 2998                   Knoxville, TN     Washington, DC (Metropolitan Area)
# 2999                   Knoxville, TN  New York City, NY (Metropolitan Area)
# 3000                   Knoxville, TN          Miami, FL (Metropolitan Area)
# 3001                   Knoxville, TN          Tampa, FL (Metropolitan Area)
#
#         fare
# 0     138.70
# 1     110.65
# 2     212.68
# 3     168.00
# 4     208.88
# ...      ...
# 2997  143.21
# 2998  199.11
# 2999  220.58
# 3000  165.02
# 3001  128.87
#
# [3002 rows x 3 columns]

# %%
games=['San Diego',
 'Chicago',
 'Los Angeles',
 'Arlington',
 'Denver',
 'Baltimore',
 'Detroit',
 'Minneapolis',
 'St. Louis',
 'Tampa Bay',
 'Toronto',
 'New York',
 'Chicago',
 'Cleveland',
 'Kansas City',
 'Oakland',
 'San Francisco',
 'Los Angeles',
 'Phoneix',
 'Washington D.C',
 'Atlanta',
 'Boston',
 'Pittsburgh',
 'Philadelphia',
 'Houston',
 'New York',
 'Miami',
 'Cincinnati',
 'Milwaukee',
 'Seattle']

# %%
df_loglat = pd.read_csv('/content/us_cities.csv')
display(df_loglat.head())
# Out:
#    ID STATE_CODE STATE_NAME      CITY          COUNTY   LATITUDE   LONGITUDE
# 0   1         AK     Alaska      Adak  Aleutians West  55.999722 -161.207778
# 1   2         AK     Alaska  Akiachak          Bethel  60.891854 -161.392330
# 2   3         AK     Alaska     Akiak          Bethel  60.890632 -161.199325
# 3   4         AK     Alaska    Akutan  Aleutians East  54.143012 -165.785368
# 4   5         AK     Alaska  Alakanuk        Kusilvak  62.746967 -164.602280

# %%
len(cities)
# Out:
# 3002

# %%
import pandas as pd

# Assume df_flights is your first DataFrame with 'city1', 'city2', and 'fare' columns
# Assume df_coords is your second DataFrame with 'CITY', 'LATITUDE', and 'LONGITUDE' columns
df_flights=cities
df_coords=df_loglat
# First, you might want to clean the city names in df_flights if they contain extra descriptions or slashes
# Here's a simple way to do it assuming the city names come before the first slash or comma:
df_flights['clean_city1'] = df_flights['city1'].str.split('/').str[0]
df_flights['clean_city2'] = df_flights['city2'].str.split('/').str[0]

df_flights['clean_city1'] = df_flights['clean_city1'].str.split(',').str[0]
df_flights['clean_city2'] = df_flights['clean_city2'].str.split(',').str[0]

# display(df_flights.head(20))
# display(df_coords.head(10))
print(len(df_flights))


# # Now, perform the merge for city1's latitude and longitude
df_merged = df_flights.merge(df_coords, left_on=['clean_city1'], right_on=['CITY'], how='left')


# # And again for city2's latitude and longitude
df_merged = df_merged.merge(df_coords, left_on=['clean_city2'], right_on=['CITY'], how='left', suffixes=('1', '2'))
display(df_merged.head())
# # Now select the relevant columns and rename them as needed
# final_df = df_merged[['city1', 'city2', 'fare', 'LATITUDE1', 'LONGITUDE1', 'LATITUDE2', 'LONGITUDE2']]

# # Rename columns for clarity
# final_df.rename(columns={
#     'LATITUDE1': 'latitude1',|
#     'LONGITUDE1': 'longitude1',
#     'LATITUDE2': 'latitude2',
#     'LONGITUDE2': 'longitude2'
# }, inplace=True)

# Your final DataFrame will have the city pairs with corresponding latitudes and longitudes
# Out:
# <ipython-input-203-2ade06603a1d>:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-203-2ade06603a1d>:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-203-2ade06603a1d>:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-203-2ade06603a1d>:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 3002
#                             city1                          city2   fare  \
# 0  Allentown/Bethlehem/Easton, PA  Tampa, FL (Metropolitan Area)  138.7
# 1  Allentown/Bethlehem/Easton, PA  Tampa, FL (Metropolitan Area)  138.7
# 2  Allentown/Bethlehem/Easton, PA  Tampa, FL (Metropolitan Area)  138.7
# 3  Allentown/Bethlehem/Easton, PA  Tampa, FL (Metropolitan Area)  138.7
# 4  Allentown/Bethlehem/Easton, PA  Tampa, FL (Metropolitan Area)  138.7
#
#   clean_city1 clean_city2      ID1 STATE_CODE1 STATE_NAME1      CITY1  \
# 0   Allentown       Tampa   4210.0          GA     Georgia  Allentown
# 1   Allentown       Tampa   4210.0          GA     Georgia  Allentown
# 2   Allentown       Tampa   4210.0          GA     Georgia  Allentown
# 3   Allentown       Tampa  16866.0          NJ  New Jersey  Allentown
# 4   Allentown       Tampa  16866.0          NJ  New Jersey  Allentown
#
#      COUNTY1  LATITUDE1  LONGITUDE1     ID2 STATE_CODE2 STATE_NAME2  CITY2  \
# 0  Wilkinson  32.653829  -83.189796  4144.0          FL     Florida  Tampa
# 1  Wilkinson  32.653829  -83.189796  4145.0          FL     Florida  Tampa
# 2  Wilkinson  32.653829  -83.189796  8728.0          KS      Kansas  Tampa
# 3   Monmouth  40.158922  -74.590930  4144.0          FL     Florida  Tampa
# 4   Monmouth  40.158922  -74.590930  4145.0          FL     Florida  Tampa
#
#         COUNTY2  LATITUDE2  LONGITUDE2
# 0           NaN  28.087900  -82.459300
# 1  Hillsborough  27.942800  -82.454900
# 2        Marion  38.553437  -97.177388
# 3           NaN  28.087900  -82.459300
# 4  Hillsborough  27.942800  -82.454900

# %%
################### JOINIGN. WITH TEAMS #####################
#games=pd.read_csv('/content/final_mlb_schedule.csv')
#df_merged = df_flights.merge(games, left_on=['clean_city1'], right_on=['CITY1'], how='left')

# %%
# Create a list of all unique cities from both 'city1' and 'city2' columns
all_cities = pd.unique(cities[['city1', 'city2']].values.ravel('K'))

# Initialize a DataFrame to hold the flight-cost matrix with all cities
flight_cost_matrix = pd.DataFrame(index=all_cities, columns=all_cities)

# Populate the matrix with the fare values
for index, row in cities.iterrows():
    flight_cost_matrix.at[row['city1'], row['city2']] = row['fare']

# Fill NaN values with 0 or some other indicator of no flight
flight_cost_matrix.fillna(0, inplace=True)

# Now you can display the flight-cost matrix
display(flight_cost_matrix)
# Out:
#                                 Allentown/Bethlehem/Easton, PA  \
# Allentown/Bethlehem/Easton, PA                               0
# Albuquerque, NM                                              0
# Atlantic City, NJ                                            0
# Colorado Springs, CO                                         0
# Dallas/Fort Worth, TX                                        0
# ...                                                        ...
# Worcester, MA                                                0
# Tallahassee, FL                                              0
# Medford, OR                                                  0
# Rockford, IL                                                 0
# Pasco/Kennewick/Richland, WA                                 0
#
#                                 Albuquerque, NM  Atlantic City, NJ  \
# Allentown/Bethlehem/Easton, PA                0                  0
# Albuquerque, NM                               0                  0
# Atlantic City, NJ                             0                  0
# Colorado Springs, CO                          0                  0
# Dallas/Fort Worth, TX                         0                  0
# ...                                         ...                ...
# Worcester, MA                                 0                  0
# Tallahassee, FL                               0                  0
# Medford, OR                                   0                  0
# Rockford, IL                                  0                  0
# Pasco/Kennewick/Richland, WA                  0                  0
#
#                                 Colorado Springs, CO  Dallas/Fort Worth, TX  \
# Allentown/Bethlehem/Easton, PA                   0.0                   0.00
# Albuquerque, NM                                  0.0                 217.74
# Atlantic City, NJ                                0.0                   0.00
# Colorado Springs, CO                             0.0                 197.87
# Dallas/Fort Worth, TX                            0.0                   0.00
# ...                                              ...                    ...
# Worcester, MA                                    0.0                   0.00
# Tallahassee, FL                                  0.0                   0.00
# Medford, OR                                      0.0                   0.00
# Rockford, IL                                     0.0                   0.00
# Pasco/Kennewick/Richland, WA                     0.0                   0.00
#
#                                 Pittsburgh, PA  Huntsville, AL  Albany, NY  \
# Allentown/Bethlehem/Easton, PA            0.00               0           0
# Albuquerque, NM                           0.00               0           0
# Atlantic City, NJ                         0.00               0           0
# Colorado Springs, CO                      0.00               0           0
# Dallas/Fort Worth, TX                   268.56               0           0
# ...                                        ...             ...         ...
# Worcester, MA                             0.00               0           0
# Tallahassee, FL                           0.00               0           0
# Medford, OR                               0.00               0           0
# Rockford, IL                              0.00               0           0
# Pasco/Kennewick/Richland, WA              0.00               0           0
#
#                                 Amarillo, TX  Denver, CO  ...  Spokane, WA  \
# Allentown/Bethlehem/Easton, PA             0        0.00  ...          0.0
# Albuquerque, NM                            0      167.51  ...          0.0
# Atlantic City, NJ                          0        0.00  ...          0.0
# Colorado Springs, CO                       0        0.00  ...          0.0
# Dallas/Fort Worth, TX                      0      179.98  ...          0.0
# ...                                      ...         ...  ...          ...
# Worcester, MA                              0        0.00  ...          0.0
# Tallahassee, FL                            0        0.00  ...          0.0
# Medford, OR                                0        0.00  ...          0.0
# Rockford, IL                               0        0.00  ...          0.0
# Pasco/Kennewick/Richland, WA               0        0.00  ...          0.0
#
#                                 Sioux Falls, SD  Provo, UT  Wilmington, NC  \
# Allentown/Bethlehem/Easton, PA              0.0        0.0             0.0
# Albuquerque, NM                             0.0        0.0             0.0
# Atlantic City, NJ                           0.0        0.0             0.0
# Colorado Springs, CO                        0.0        0.0             0.0
# Dallas/Fort Worth, TX                       0.0        0.0             0.0
# ...                                         ...        ...             ...
# Worcester, MA                               0.0        0.0             0.0
# Tallahassee, FL                             0.0        0.0             0.0
# Medford, OR                                 0.0        0.0             0.0
# Rockford, IL                                0.0        0.0             0.0
# Pasco/Kennewick/Richland, WA                0.0        0.0             0.0
#
#                                 Mission/McAllen/Edinburg, TX  Worcester, MA  \
# Allentown/Bethlehem/Easton, PA                           0.0            0.0
# Albuquerque, NM                                          0.0            0.0
# Atlantic City, NJ                                        0.0            0.0
# Colorado Springs, CO                                     0.0            0.0
# Dallas/Fort Worth, TX                                    0.0            0.0
# ...                                                      ...            ...
# Worcester, MA                                            0.0            0.0
# Tallahassee, FL                                          0.0            0.0
# Medford, OR                                              0.0            0.0
# Rockford, IL                                             0.0            0.0
# Pasco/Kennewick/Richland, WA                             0.0            0.0
#
#                                 Tallahassee, FL  Medford, OR  Rockford, IL  \
# Allentown/Bethlehem/Easton, PA              0.0          0.0           0.0
# Albuquerque, NM                             0.0          0.0           0.0
# Atlantic City, NJ                           0.0          0.0           0.0
# Colorado Springs, CO                        0.0          0.0           0.0
# Dallas/Fort Worth, TX                       0.0          0.0           0.0
# ...                                         ...          ...           ...
# Worcester, MA                               0.0          0.0           0.0
# Tallahassee, FL                             0.0          0.0           0.0
# Medford, OR                                 0.0          0.0           0.0
# Rockford, IL                                0.0          0.0           0.0
# Pasco/Kennewick/Richland, WA                0.0          0.0           0.0
#
#                                 Pasco/Kennewick/Richland, WA
# Allentown/Bethlehem/Easton, PA                           0.0
# Albuquerque, NM                                          0.0
# Atlantic City, NJ                                        0.0
# Colorado Springs, CO                                     0.0
# Dallas/Fort Worth, TX                                    0.0
# ...                                                      ...
# Worcester, MA                                            0.0
# Tallahassee, FL                                          0.0
# Medford, OR                                              0.0
# Rockford, IL                                             0.0
# Pasco/Kennewick/Richland, WA                             0.0
#
# [128 rows x 128 columns]

# %%
display(games)
# Out:
# ['San Diego',
#  'Chicago',
#  'Los Angeles',
#  'Arlington',
#  'Denver',
#  'Baltimore',
#  'Detroit',
#  'Minneapolis',
#  'St. Louis',
#  'Tampa Bay',
#  'Toronto',
#  'New York',
#  'Chicago',
#  'Cleveland',
#  'Kansas City',
#  'Oakland',
#  'San Francisco',
#  'Los Angeles',
#  'Phoneix',
#  'Washington D.C',
#  'Atlanta',
#  'Boston',
#  'Pittsburgh',
#  'Philadelphia',
#  'Houston',
#  'New York',
#  'Miami',
#  'Cincinnati',
#  'Milwaukee',
#  'Seattle']

# %%
df_filtered=df_merged[['CITY1','CITY2','fare','LONGITUDE1','LATITUDE1','LONGITUDE2','LATITUDE2']]
df_filtered = df_filtered.drop_duplicates(subset=['CITY1', 'CITY2']).reset_index()

# %%
display(df_filtered)
# Out:
#        index          CITY1          CITY2    fare  LONGITUDE1  LATITUDE1  \
# 0          0      Allentown          Tampa  138.70  -83.189796  32.653829
# 1         12      Allentown        Sanford  110.65  -83.189796  32.653829
# 2         40    Albuquerque         Dallas  212.68 -106.642300  35.093600
# 3         50    Albuquerque         Denver  168.00 -106.642300  35.093600
# 4         60    Albuquerque         Austin  208.88 -106.642300  35.093600
# ...      ...            ...            ...     ...         ...        ...
# 1094  120021       Portland            NaN  297.13  -91.513935  33.231773
# 1095  120954     Santa Rosa        Seattle  186.02 -122.751722  38.443123
# 1096  120959           Bend  San Francisco  228.42 -121.293632  44.092788
# 1097  121233           Reno     Washington  415.82 -119.811275  39.526812
# 1098  121833  Santa Barbara        Seattle  228.59 -119.707820  34.419668
#
#       LONGITUDE2  LATITUDE2
# 0     -82.459300  28.087900
# 1    -105.928588  37.208724
# 2     -84.827791  33.916315
# 3    -105.007985  39.840562
# 4     -91.959398  35.028369
# ...          ...        ...
# 1094         NaN        NaN
# 1095 -122.330456  47.611435
# 1096 -122.418300  37.775000
# 1097  -93.673529  33.754596
# 1098 -122.330456  47.611435
#
# [1099 rows x 8 columns]

# %%
#df_1=df_filtered.iloc[:5,:].reset_index()

# %%
#display(df_1)
# Out:
# Empty DataFrame
# Columns: [level_0, index, LATITUDE1, LATITUDE2, LONGITUDE1, LONGITUDE2, fare, CITY1, CITY2]
# Index: []

# %%
import pandas as pd

# Suppose df is your dataframe and city_list is your list of cities.
# Replace this with your actual dataframe and city list.
#df = pd.read_csv('path_to_your_dataframe.csv')


# Filter rows where both CITY1 and CITY2 are in the city_list
df_filtered = df_filtered[df_filtered['CITY1'].isin(games) & df_filtered['CITY2'].isin(games)]

# %%
df_filtered
# Out:
#      index       CITY1          CITY2    fare  LONGITUDE1  LATITUDE1  \
# 77    3021  Pittsburgh        Seattle  238.91  -79.952524  40.474536
# 79    3048  Pittsburgh  San Francisco  313.49  -79.952524  40.474536
# 88    3913      Denver     Pittsburgh  255.95 -105.007985  39.840562
# 92    4123      Denver        Seattle  175.33 -105.007985  39.840562
# 98    4653      Denver        Detroit  231.55 -105.007985  39.840562
# 100   4733      Denver        Houston  205.28 -105.007985  39.840562
# 102   4893      Denver    Minneapolis  168.89 -105.007985  39.840562
# 108   5043      Denver  San Francisco  208.06 -105.007985  39.840562
#
#      LONGITUDE2  LATITUDE2
# 77  -122.330456  47.611435
# 79  -122.418300  37.775000
# 88   -79.952524  40.474536
# 92  -122.330456  47.611435
# 98   -88.160630  34.010874
# 100 -149.841111  61.633611
# 102  -97.668778  39.129487
# 108 -122.418300  37.775000

# %%
'import plotly.graph_objs as go
import pandas as pd

# Assuming df_filtered is your DataFrame with the necessary columns

# Create the map figure
fig = go.Figure()

# Dictionary to track which cities have been plotted
plotted_cities = {}

# Add the flight paths
for i, row in df_filtered.iterrows():
    print(f"Adding flight path {i}: {row['CITY1']} to {row['CITY2']}")
    # Add flight path
    fig.add_trace(
        go.Scattergeo(
            locationmode='USA-states',
            lon=[row['LONGITUDE1'], row['LONGITUDE2']],
            lat=[row['LATITUDE1'], row['LATITUDE2']],
            mode='lines',
            #text=
            line=dict(width=2, color='rgba(135, 167, 187, 0.5)'),  # Adjusted color and opacity
            opacity=0.6,  # Adjusted opacity for transparency
            hoverinfo='skip',  # Skip hover info for lines
        )
    )
        # Calculate midpoint coordinates
    mid_lon = (row['LONGITUDE1'] + row['LONGITUDE2']) / 2
    mid_lat = (row['LATITUDE1'] + row['LATITUDE2']) / 2

    print("long1", row['LONGITUDE1'])
    print("long2", row['LONGITUDE2'])
    print("mid_long: ",mid_lon)

    # Add midpoint marker with hover text
    fig.add_trace(
        go.Scattergeo(
            locationmode='USA-states',
            lon=[mid_lon],
            lat=[mid_lat],
            mode='markers',
            marker=dict(
                size=0,
                opacity=0
            ),
            hoverinfo='text',
            text=f"{row['CITY1']} to {row['CITY2']} fare: ${row['fare']}"
        )
    )
    # Calculate midpoint coordinates
    mid_lon = (row['LONGITUDE1'] + row['LONGITUDE2']) / 2
    mid_lat = (row['LATITUDE1'] + row['LATITUDE2']) / 2

    # Add annotation for the midpoint with fare information
    fig.add_annotation(
        x=mid_lon,
        y=mid_lat,
        text=f"{row['CITY1']} to {row['CITY2']} fare: ${row['fare']}",
        showarrow=False,
        font=dict(color='black', size=10),
        align='center',  # Center the annotation
        valign='middle'  # Center the annotation
    )


   # Add marker for CITY1 if not already plotted
    if row['CITY1'] not in plotted_cities:
        fig.add_trace(
            go.Scattergeo(
                locationmode='USA-states',
                lon=[row['LONGITUDE1']],
                lat=[row['LATITUDE1']],
                text=row['CITY1'],
                mode='markers+text',
                marker=dict(size=5, color='red'),
                hoverinfo='skip'  # Skip hover info for markers
            )
        )
        plotted_cities[row['CITY1']] = True

    # Add marker for CITY2 if not already plotted
    if row['CITY2'] not in plotted_cities:
        fig.add_trace(
            go.Scattergeo(
                locationmode='USA-states',
                lon=[row['LONGITUDE2']],
                lat=[row['LATITUDE2']],
                text=row['CITY2'],
                mode='markers+text',
                marker=dict(size=5, color='red'),
                hoverinfo='skip'  # Skip hover info for markers
            )
        )
        plotted_cities[row['CITY2']] = True


# Update the layout of the map
fig.update_layout(
    title_text='Flight Cost Visualization',
    showlegend=False,
    geo=dict(
        scope='usa',
        projection_type='albers usa',
        showland=True,
        landcolor='rgb(200, 200, 200)',
        subunitwidth=1,
        countrywidth=1,
        subunitcolor='rgb(255,255,255)',
        countrycolor='rgb(255,255,255)'
    ),
)

# Display the figure
fig.show()

# Alternatively, you can save the figure as an HTML file
fig.write_html("flight_cost_visualization.html")
# Out:
# Adding flight path 77: Pittsburgh to Seattle
# long1 -79.952524
# long2 -122.330456
# mid_long:  -101.14149
# Adding flight path 79: Pittsburgh to San Francisco
# long1 -79.952524
# long2 -122.4183
# mid_long:  -101.185412
# Adding flight path 88: Denver to Pittsburgh
# long1 -105.007985
# long2 -79.952524
# mid_long:  -92.4802545
# Adding flight path 92: Denver to Seattle
# long1 -105.007985
# long2 -122.330456
# mid_long:  -113.6692205
# Adding flight path 98: Denver to Detroit
# long1 -105.007985
# long2 -88.16063
# mid_long:  -96.5843075
# Adding flight path 100: Denver to Houston
# long1 -105.007985
# long2 -149.841111
# mid_long:  -127.42454800000002
# Adding flight path 102: Denver to Minneapolis
# long1 -105.007985
# long2 -97.668778
# mid_long:  -101.3383815
# Adding flight path 108: Denver to San Francisco
# long1 -105.007985
# long2 -122.4183
# mid_long:  -113.7131425
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a03eb320-22ac-400c-a7c6-ddb435325f41" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a03eb320-22ac-400c-a7c6-ddb435325f41")) {                    Plotly.newPlot(                        "a03eb320-22ac-400c-a7c6-ddb435325f41",                        [{"hoverinfo":"skip","lat":[40.474536,47.611435],"line":{"color":"rgba(135, 167, 187, 0.5)","width":2},"locationmode":"USA-states","lon":[-79.952524,-122.330456],"mode":"lines","opacity":0.6,"type":"scattergeo"},{"hoverinfo":"text","lat":[44.0429855],"locationmode":"USA-states","lon":[-101.14149],"marker":{"opacity":0,"size":0},"mode":"markers","text":"Pittsburgh to Seattle fare: $238.91","type":"scattergeo"},{"hoverinfo":"skip","lat":[40.474536],"locationmode":"USA-states","lon":[-79.952524],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Pittsburgh","type":"scattergeo"},{"hoverinfo":"skip","lat":[47.611435],"locationmode":"USA-states","lon":[-122.330456],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Seattle","type":"scattergeo"},{"hoverinfo":"skip","lat":[40.474536,37.775],"line":{"color":"rgba(135, 167, 187, 0.5)","width":2},"locationmode":"USA-states","lon":[-79.952524,-122.4183],"mode":"lines","opacity":0.6,"type":"scattergeo"},{"hoverinfo":"text","lat":[39.124768],"locationmode":"USA-states","lon":[-101.185412],"marker":{"opacity":0,"size":0},"mode":"markers","text":"Pittsburgh to San Francisco fare: $313.49","type":"scattergeo"},{"hoverinfo":"skip","lat":[37.775],"locationmode":"USA-states","lon":[-122.4183],"marker":{"color":"red","size":5},"mode":"markers+text","text":"San Francisco","type":"scattergeo"},{"hoverinfo":"skip","lat":[39.840562,40.474536],"line":{"color":"rgba(135, 167, 187, 0.5)","width":2},"locationmode":"USA-states","lon":[-105.007985,-79.952524],"mode":"lines","opacity":0.6,"type":"scattergeo"},{"hoverinfo":"text","lat":[40.157549],"locationmode":"USA-states","lon":[-92.4802545],"marker":{"opacity":0,"size":0},"mode":"markers","text":"Denver to Pittsburgh fare: $255.95","type":"scattergeo"},{"hoverinfo":"skip","lat":[39.840562],"locationmode":"USA-states","lon":[-105.007985],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Denver","type":"scattergeo"},{"hoverinfo":"skip","lat":[39.840562,47.611435],"line":{"color":"rgba(135, 167, 187, 0.5)","width":2},"locationmode":"USA-states","lon":[-105.007985,-122.330456],"mode":"lines","opacity":0.6,"type":"scattergeo"},{"hoverinfo":"text","lat":[43.7259985],"locationmode":"USA-states","lon":[-113.6692205],"marker":{"opacity":0,"size":0},"mode":"markers","text":"Denver to Seattle fare: $175.33","type":"scattergeo"},{"hoverinfo":"skip","lat":[39.840562,34.010874],"line":{"color":"rgba(135, 167, 187, 0.5)","width":2},"locationmode":"USA-states","lon":[-105.007985,-88.16063],"mode":"lines","opacity":0.6,"type":"scattergeo"},{"hoverinfo":"text","lat":[36.925718],"locationmode":"USA-states","lon":[-96.5843075],"marker":{"opacity":0,"size":0},"mode":"markers","text":"Denver to Detroit fare: $231.55","type":"scattergeo"},{"hoverinfo":"skip","lat":[34.010874],"locationmode":"USA-states","lon":[-88.16063],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Detroit","type":"scattergeo"},{"hoverinfo":"skip","lat":[39.840562,61.633611],"line":{"color":"rgba(135, 167, 187, 0.5)","width":2},"locationmode":"USA-states","lon":[-105.007985,-149.841111],"mode":"lines","opacity":0.6,"type":"scattergeo"},{"hoverinfo":"text","lat":[50.737086500000004],"locationmode":"USA-states","lon":[-127.42454800000002],"marker":{"opacity":0,"size":0},"mode":"markers","text":"Denver to Houston fare: $205.28","type":"scattergeo"},{"hoverinfo":"skip","lat":[61.633611],"locationmode":"US ...

# %%
df_filtered=df_filtered.iloc[:8,:]

# %%
#LIMIT TO 8 cities


import plotly.graph_objs as go
import pandas as pd

# Assuming df_filtered is your DataFrame with the necessary columns

# Create the map figure
fig = go.Figure()

# Dictionary to track which cities have been plotted
plotted_cities = {}

# Add the flight paths
for i, row in df_filtered.iterrows():
    print(f"Adding flight path {i}: {row['CITY1']} to {row['CITY2']}")
    # Add flight path
    fig.add_trace(
        go.Scattergeo(
            locationmode='USA-states',
            lon=[row['LONGITUDE1'], row['LONGITUDE2']],
            lat=[row['LATITUDE1'], row['LATITUDE2']],
            mode='lines',
            text=f"{row['CITY1']} to {row['CITY2']} fare: ${row['fare']}",
            line=dict(width=2, color='rgba(135, 167, 187, 0.5)'),  # Adjusted color and opacity
            opacity=0.8,  # Adjusted opacity for transparency
            #hoverinfo='skip',  # Skip hover info for lines
        )
    )
        # Calculate midpoint coordinates
    mid_lon = (row['LONGITUDE1'] + row['LONGITUDE2']) / 2
    mid_lat = (row['LATITUDE1'] + row['LATITUDE2']) / 2
    print("long1", row['LONGITUDE1'])
    print("long2", row['LONGITUDE2'])
    print("mid_long: ",mid_lon)
    # Add midpoint marker with hover text
    fig.add_trace(
        go.Scattergeo(
            locationmode='USA-states',
            lon=[mid_lon],
            lat=[mid_lat],
            mode='markers',
            marker=dict(
                size=0,
                opacity=0
            ),
           # hoverinfo="skip",
            text=f"{row['CITY1']} to {row['CITY2']} fare: ${row['fare']}"
        )
    )
    fig.add_trace(go.Scattergeo(
        #rem mid
            lon=[mid_lon],
            lat=[mid_lat],
            mode="text",
            name="Text",
            text=f"${row['fare']}",
            textposition='top center'
                  ))

    fig.add_annotation(
        #removed mid pt
            x=[mid_lon],
            y=[mid_lat],
            text=f"${row['fare']}",  # Text here is the fare amount
            showarrow=True,
            font=dict(
                size=8,  # Size of the annotation text
                color='black'  # Color of the annotation text
            ),
            bgcolor='white',  # Background color of the annotation
            bordercolor='black',  # Border color of the annotation
            borderpad=3,  # Padding around the text inside the annotation
            borderwidth=1  # Width of the border around the annotation
        )


    print([mid_lon])
   # mid_lon = (row['LONGITUDE1'] + row['LONGITUDE2']) / 2
    #mid_lat = (row['LATITUDE1'] + row['LATITUDE2']) / 2





   # Add marker for CITY1 if not already plotted
    if row['CITY1'] not in plotted_cities:
        fig.add_trace(
            go.Scattergeo(
                locationmode='USA-states',
                lon=[row['LONGITUDE1']],
                lat=[row['LATITUDE1']],
                text=row['CITY1'],
                mode='markers+text',
                marker=dict(size=5, color='red'),
                hoverinfo='skip'  # Skip hover info for markers
            )
        )
        plotted_cities[row['CITY1']] = True

    # Add marker for CITY2 if not already plotted
    if row['CITY2'] not in plotted_cities:
        fig.add_trace(
            go.Scattergeo(
                locationmode='USA-states',
                lon=[row['LONGITUDE2']],
                lat=[row['LATITUDE2']],
                text=row['CITY2'],
                mode='markers+text',
                marker=dict(size=5, color='red'),
                hoverinfo='skip'  # Skip hover info for markers
            )
        )
        plotted_cities[row['CITY2']] = True



# Update the layout of the map
fig.update_layout(
    title_text='Flight Cost Visualization',
    showlegend=False,
    geo=dict(
        scope='usa',
        projection_type='albers usa',
        showland=True,
        #landcolor='rgb(150, 150, 150)',
        subunitwidth=1,
        countrywidth=1,
        subunitcolor='rgb(255,255,255)',
        countrycolor='rgb(255,255,255)'
    ),
)

# Display the figure
fig.show()

# Alternatively, you can save the figure as an HTML file
fig.write_html("flight_cost_visualization.html")
# Out:
# Adding flight path 77: Pittsburgh to Seattle
# long1 -79.952524
# long2 -122.330456
# mid_long:  -101.14149
# [-101.14149]
# Adding flight path 79: Pittsburgh to San Francisco
# long1 -79.952524
# long2 -122.4183
# mid_long:  -101.185412
# [-101.185412]
# Adding flight path 88: Denver to Pittsburgh
# long1 -105.007985
# long2 -79.952524
# mid_long:  -92.4802545
# [-92.4802545]
# Adding flight path 92: Denver to Seattle
# long1 -105.007985
# long2 -122.330456
# mid_long:  -113.6692205
# [-113.6692205]
# Adding flight path 98: Denver to Detroit
# long1 -105.007985
# long2 -88.16063
# mid_long:  -96.5843075
# [-96.5843075]
# Adding flight path 100: Denver to Houston
# long1 -105.007985
# long2 -149.841111
# mid_long:  -127.42454800000002
# [-127.42454800000002]
# Adding flight path 102: Denver to Minneapolis
# long1 -105.007985
# long2 -97.668778
# mid_long:  -101.3383815
# [-101.3383815]
# Adding flight path 108: Denver to San Francisco
# long1 -105.007985
# long2 -122.4183
# mid_long:  -113.7131425
# [-113.7131425]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a534b554-3df6-4750-921f-70354380ca17" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a534b554-3df6-4750-921f-70354380ca17")) {                    Plotly.newPlot(                        "a534b554-3df6-4750-921f-70354380ca17",                        [{"lat":[40.474536,47.611435],"line":{"color":"rgba(135, 167, 187, 0.5)","width":2},"locationmode":"USA-states","lon":[-79.952524,-122.330456],"mode":"lines","opacity":0.8,"text":"Pittsburgh to Seattle fare: $238.91","type":"scattergeo"},{"lat":[44.0429855],"locationmode":"USA-states","lon":[-101.14149],"marker":{"opacity":0,"size":0},"mode":"markers","text":"Pittsburgh to Seattle fare: $238.91","type":"scattergeo"},{"lat":[44.0429855],"lon":[-101.14149],"mode":"text","name":"Text","text":"$238.91","textposition":"top center","type":"scattergeo"},{"hoverinfo":"skip","lat":[40.474536],"locationmode":"USA-states","lon":[-79.952524],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Pittsburgh","type":"scattergeo"},{"hoverinfo":"skip","lat":[47.611435],"locationmode":"USA-states","lon":[-122.330456],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Seattle","type":"scattergeo"},{"lat":[40.474536,37.775],"line":{"color":"rgba(135, 167, 187, 0.5)","width":2},"locationmode":"USA-states","lon":[-79.952524,-122.4183],"mode":"lines","opacity":0.8,"text":"Pittsburgh to San Francisco fare: $313.49","type":"scattergeo"},{"lat":[39.124768],"locationmode":"USA-states","lon":[-101.185412],"marker":{"opacity":0,"size":0},"mode":"markers","text":"Pittsburgh to San Francisco fare: $313.49","type":"scattergeo"},{"lat":[39.124768],"lon":[-101.185412],"mode":"text","name":"Text","text":"$313.49","textposition":"top center","type":"scattergeo"},{"hoverinfo":"skip","lat":[37.775],"locationmode":"USA-states","lon":[-122.4183],"marker":{"color":"red","size":5},"mode":"markers+text","text":"San Francisco","type":"scattergeo"},{"lat":[39.840562,40.474536],"line":{"color":"rgba(135, 167, 187, 0.5)","width":2},"locationmode":"USA-states","lon":[-105.007985,-79.952524],"mode":"lines","opacity":0.8,"text":"Denver to Pittsburgh fare: $255.95","type":"scattergeo"},{"lat":[40.157549],"locationmode":"USA-states","lon":[-92.4802545],"marker":{"opacity":0,"size":0},"mode":"markers","text":"Denver to Pittsburgh fare: $255.95","type":"scattergeo"},{"lat":[40.157549],"lon":[-92.4802545],"mode":"text","name":"Text","text":"$255.95","textposition":"top center","type":"scattergeo"},{"hoverinfo":"skip","lat":[39.840562],"locationmode":"USA-states","lon":[-105.007985],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Denver","type":"scattergeo"},{"lat":[39.840562,47.611435],"line":{"color":"rgba(135, 167, 187, 0.5)","width":2},"locationmode":"USA-states","lon":[-105.007985,-122.330456],"mode":"lines","opacity":0.8,"text":"Denver to Seattle fare: $175.33","type":"scattergeo"},{"lat":[43.7259985],"locationmode":"USA-states","lon":[-113.6692205],"marker":{"opacity":0,"size":0},"mode":"markers","text":"Denver to Seattle fare: $175.33","type":"scattergeo"},{"lat":[43.7259985],"lon":[-113.6692205],"mode":"text","name":"Text","text":"$175.33","textposition":"top center","type":"scattergeo"},{"lat":[39.840562,34.010874],"line":{"color":"rgba(135, 167, 187, 0.5)","width":2},"locationmode":"USA-states","lon":[-105.007985,-88.16063],"mode":"lines","opacity":0.8,"text":"Denver to Detroit fare: $231.55","type":"scattergeo"},{"lat":[36.925718],"locationmode":"USA-states","lon":[-96.5843075],"marker":{"opacity":0,"size":0},"mode":"markers","text":"Denver to Detroit fare: $231.55","type":"scattergeo"},{"lat":[36.925718],"lon":[-96.5843075],"mode":"text","name":"Text","text":"$231.55","textposit ...

# %%
import plotly.graph_objs as go
import pandas as pd

# Assuming df_filtered is your DataFrame with the necessary columns

# Create the map figure
fig = go.Figure()

# Dictionary to track which cities have been plotted
plotted_cities = {}

# Add the flight paths
for i, row in df_filtered.iterrows():
    print(f"Adding flight path {i}: {row['CITY1']} to {row['CITY2']}")
    # Add flight path
    fig.add_trace(
        go.Scattergeo(
            locationmode='USA-states',
            lon=[row['LONGITUDE1'], row['LONGITUDE2']],
            lat=[row['LATITUDE1'], row['LATITUDE2']],
            mode='lines',
            line=dict(width=2, color='rgba(135, 167, 187, 0.5)'),  # Adjusted color and opacity
            opacity=0.6,  # Adjusted opacity for transparency
            hoverinfo='text',
            text=f"{row['CITY1']} to {row['CITY2']} fare: ${row['fare']}",  # Text displayed on hover
        )
    #print(i," ",row)
    )
######

# create mid points

######
    # Add marker for CITY1 if not already plotted
    if row['CITY1'] not in plotted_cities:
        fig.add_trace(
            go.Scattergeo(
                locationmode='USA-states',
                lon=[row['LONGITUDE1']],
                lat=[row['LATITUDE1']],
                text=row['CITY1'],
                mode='markers+text',
                marker=dict(size=5, color='red'),
                hoverinfo='skip'  # Skip hover info for markers
            )
        )
        plotted_cities[row['CITY1']] = True

    # Add marker for CITY2 if not already plotted
    if row['CITY2'] not in plotted_cities:
        fig.add_trace(
            go.Scattergeo(
                locationmode='USA-states',
                lon=[row['LONGITUDE2']],
                lat=[row['LATITUDE2']],
                text=row['CITY2'],
                mode='markers+text',
                marker=dict(size=5, color='red'),
                hoverinfo='skip'  # Skip hover info for markers
            )
        )
        plotted_cities[row['CITY2']] = True

# Update the layout of the map
fig.update_layout(
    title_text='Flight Cost Visualization',
    showlegend=False,
    geo=dict(
        scope='usa',
        projection_type='albers usa',
        showland=True,
        landcolor='rgb(200, 200, 200)',
        subunitwidth=1,
        countrywidth=1,
        subunitcolor='rgb(255,255,255)',
        countrycolor='rgb(255,255,255)'
    ),
)

# Display the figure
fig.show()

# Alternatively, you can save the figure as an HTML file
fig.write_html("flight_cost_visualization.html")
# Out:
# Adding flight path 0: Allentown to Tampa
# Adding flight path 1: Allentown to Sanford
# Adding flight path 2: Albuquerque to Dallas
# Adding flight path 3: Albuquerque to Denver
# Adding flight path 4: Albuquerque to Austin
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b2de5dd5-0dc4-48d3-a2e6-f357a35c8cc3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2de5dd5-0dc4-48d3-a2e6-f357a35c8cc3")) {                    Plotly.newPlot(                        "b2de5dd5-0dc4-48d3-a2e6-f357a35c8cc3",                        [{"hoverinfo":"text","lat":[32.653829,28.0879],"line":{"color":"rgba(135, 167, 187, 0.5)","width":2},"locationmode":"USA-states","lon":[-83.189796,-82.4593],"mode":"lines","opacity":0.6,"text":"Allentown to Tampa fare: $138.7","type":"scattergeo"},{"hoverinfo":"skip","lat":[32.653829],"locationmode":"USA-states","lon":[-83.189796],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Allentown","type":"scattergeo"},{"hoverinfo":"skip","lat":[28.0879],"locationmode":"USA-states","lon":[-82.4593],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Tampa","type":"scattergeo"},{"hoverinfo":"text","lat":[32.653829,37.208724],"line":{"color":"rgba(135, 167, 187, 0.5)","width":2},"locationmode":"USA-states","lon":[-83.189796,-105.928588],"mode":"lines","opacity":0.6,"text":"Allentown to Sanford fare: $110.65","type":"scattergeo"},{"hoverinfo":"skip","lat":[37.208724],"locationmode":"USA-states","lon":[-105.928588],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Sanford","type":"scattergeo"},{"hoverinfo":"text","lat":[35.0936,33.916315],"line":{"color":"rgba(135, 167, 187, 0.5)","width":2},"locationmode":"USA-states","lon":[-106.6423,-84.827791],"mode":"lines","opacity":0.6,"text":"Albuquerque to Dallas fare: $212.68","type":"scattergeo"},{"hoverinfo":"skip","lat":[35.0936],"locationmode":"USA-states","lon":[-106.6423],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Albuquerque","type":"scattergeo"},{"hoverinfo":"skip","lat":[33.916315],"locationmode":"USA-states","lon":[-84.827791],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Dallas","type":"scattergeo"},{"hoverinfo":"text","lat":[35.0936,39.840562],"line":{"color":"rgba(135, 167, 187, 0.5)","width":2},"locationmode":"USA-states","lon":[-106.6423,-105.007985],"mode":"lines","opacity":0.6,"text":"Albuquerque to Denver fare: $168.0","type":"scattergeo"},{"hoverinfo":"skip","lat":[39.840562],"locationmode":"USA-states","lon":[-105.007985],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Denver","type":"scattergeo"},{"hoverinfo":"text","lat":[35.0936,35.028369],"line":{"color":"rgba(135, 167, 187, 0.5)","width":2},"locationmode":"USA-states","lon":[-106.6423,-91.959398],"mode":"lines","opacity":0.6,"text":"Albuquerque to Austin fare: $208.88","type":"scattergeo"},{"hoverinfo":"skip","lat":[35.028369],"locationmode":"USA-states","lon":[-91.959398],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Austin","type":"scattergeo"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{ ...

# %%
#######2.0 test
import plotly.graph_objs as go
import pandas as pd

# Assuming df_filtered is your DataFrame with the necessary columns

# Create the map figure
fig = go.Figure()

# Dictionary to track which cities have been plotted
plotted_cities = {}

# Add the flight paths
for i, row in df_filtered.iterrows():
    # Add flight path
    fig.add_trace(
        go.Scattergeo(
            locationmode='USA-states',
            lon=[row['LONGITUDE1'], row['LONGITUDE2']],
            lat=[row['LATITUDE1'], row['LATITUDE2']],
            mode='lines',
            line=dict(width=2, color='rgba(135, 180, 180, 0.8)'),  # Adjusted color with alpha for opacity
            hoverinfo='text',
            text=f"{row['CITY1']} to {row['CITY2']} fare: ${row['fare']}",  # Text displayed on hover
        )
    )

    # Add marker for CITY1 if not already plotted
    if row['CITY1'] not in plotted_cities:
        fig.add_trace(
            go.Scattergeo(
                locationmode='USA-states',
                lon=[row['LONGITUDE1']],
                lat=[row['LATITUDE1']],
                text=row['CITY1'],
                mode='markers+text',
                marker=dict(size=5, color='red'),
                #hoverinfo='skip'  # Skip hover info for markers
            )
        )
        plotted_cities[row['CITY1']] = True

    # Add marker for CITY2 if not already plotted
    if row['CITY2'] not in plotted_cities:
        fig.add_trace(
            go.Scattergeo(
                locationmode='USA-states',
                lon=[row['LONGITUDE2']],
                lat=[row['LATITUDE2']],
                text=row['CITY2'],
                mode='markers+text',
                marker=dict(size=5, color='red'),
                #hoverinfo='skip'  # Skip hover info for markers
            )
        )
        plotted_cities[row['CITY2']] = True

# Update the layout of the map
fig.update_layout(
    title_text='Flight Cost Visualization',
    showlegend=False,
    geo=dict(
        scope='usa',
        projection_type='albers usa',
        showland=True,
        landcolor='rgb(200, 200, 200)',
        subunitwidth=1,
        countrywidth=1,
        subunitcolor='rgb(255,255,255)',
        countrycolor='rgb(255,255,255)'
    ),
)

# Display the figure
fig.show()

# Alternatively, you can save the figure as an HTML file
fig.write_html("flight_cost_visualization.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="eeb9b5ec-cbd0-4ccc-ade1-83ccb7ea82cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eeb9b5ec-cbd0-4ccc-ade1-83ccb7ea82cc")) {                    Plotly.newPlot(                        "eeb9b5ec-cbd0-4ccc-ade1-83ccb7ea82cc",                        [{"hoverinfo":"text","lat":[32.653829,28.0879],"line":{"color":"rgba(135, 180, 180, 0.8)","width":2},"locationmode":"USA-states","lon":[-83.189796,-82.4593],"mode":"lines","text":"Allentown to Tampa fare: $138.7","type":"scattergeo"},{"lat":[32.653829],"locationmode":"USA-states","lon":[-83.189796],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Allentown","type":"scattergeo"},{"lat":[28.0879],"locationmode":"USA-states","lon":[-82.4593],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Tampa","type":"scattergeo"},{"hoverinfo":"text","lat":[32.653829,37.208724],"line":{"color":"rgba(135, 180, 180, 0.8)","width":2},"locationmode":"USA-states","lon":[-83.189796,-105.928588],"mode":"lines","text":"Allentown to Sanford fare: $110.65","type":"scattergeo"},{"lat":[37.208724],"locationmode":"USA-states","lon":[-105.928588],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Sanford","type":"scattergeo"},{"hoverinfo":"text","lat":[35.0936,33.916315],"line":{"color":"rgba(135, 180, 180, 0.8)","width":2},"locationmode":"USA-states","lon":[-106.6423,-84.827791],"mode":"lines","text":"Albuquerque to Dallas fare: $212.68","type":"scattergeo"},{"lat":[35.0936],"locationmode":"USA-states","lon":[-106.6423],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Albuquerque","type":"scattergeo"},{"lat":[33.916315],"locationmode":"USA-states","lon":[-84.827791],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Dallas","type":"scattergeo"},{"hoverinfo":"text","lat":[35.0936,39.840562],"line":{"color":"rgba(135, 180, 180, 0.8)","width":2},"locationmode":"USA-states","lon":[-106.6423,-105.007985],"mode":"lines","text":"Albuquerque to Denver fare: $168.0","type":"scattergeo"},{"lat":[39.840562],"locationmode":"USA-states","lon":[-105.007985],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Denver","type":"scattergeo"},{"hoverinfo":"text","lat":[35.0936,35.028369],"line":{"color":"rgba(135, 180, 180, 0.8)","width":2},"locationmode":"USA-states","lon":[-106.6423,-91.959398],"mode":"lines","text":"Albuquerque to Austin fare: $208.88","type":"scattergeo"},{"lat":[35.028369],"locationmode":"USA-states","lon":[-91.959398],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Austin","type":"scattergeo"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556, ...

# %%
import plotly.graph_objs as go
import pandas as pd

# Assuming df_filtered is your DataFrame with the necessary columns

# Create the map figure
fig = go.Figure()

# Dictionary to track which cities have been plotted
plotted_cities = {}

# Add the flight paths
for i, row in df_filtered.iterrows():
    # Add flight path
    fig.add_trace(
        go.Scattergeo(
            locationmode='USA-states',
            lon=[row['LONGITUDE1'], row['LONGITUDE2']],
            lat=[row['LATITUDE1'], row['LATITUDE2']],
            mode='lines',
            line=dict(
                width=2,
                color='rgba(135, 180, 180, 0.8)',  # Adjusted color with alpha for opacity
            ),
            hoverinfo='none'  # Remove hover info for the lines
        )
    )

    # Add marker for CITY1 if not already plotted
    if row['CITY1'] not in plotted_cities:
        fig.add_trace(
            go.Scattergeo(
                locationmode='USA-states',
                lon=[row['LONGITUDE1']],
                lat=[row['LATITUDE1']],
                text=row['CITY1'],
                mode='markers+text',
                marker=dict(size=5, color='red'),
                hoverinfo='skip'  # Skip hover info for markers
            )
        )
        plotted_cities[row['CITY1']] = True

    # Add marker for CITY2 if not already plotted
    if row['CITY2'] not in plotted_cities:
        fig.add_trace(
            go.Scattergeo(
                locationmode='USA-states',
                lon=[row['LONGITUDE2']],
                lat=[row['LATITUDE2']],
                text=row['CITY2'],
                mode='markers+text',
                marker=dict(size=5, color='red'),
                hoverinfo='skip'  # Skip hover info for markers
            )
        )
        plotted_cities[row['CITY2']] = True

    # Add annotation for fare
    fare_annotation = go.Annotation(
        x=(row['LONGITUDE1'] + row['LONGITUDE2']) / 2,  # Compute midpoint for x
        y=(row['LATITUDE1'] + row['LATITUDE2']) / 2,  # Compute midpoint for y
        xref='x',
        yref='y',
        text=f"Fare: ${row['fare']}",
        showarrow=False,
        font=dict(color='black', size=10),
    )
    fig.add_annotation(fare_annotation)

# Update the layout of the map
fig.update_layout(
    title_text='Flight Cost Visualization',
    showlegend=False,
    geo=dict(
        scope='usa',
        projection_type='albers usa',
        showland=True,
        landcolor='rgb(200, 200, 200)',
        subunitwidth=1,
        countrywidth=1,
        subunitcolor='rgb(255,255,255)',
        countrycolor='rgb(255,255,255)'
    ),
)

# Display the figure
fig.show()

# Alternatively, you can save the figure as an HTML file
fig.write_html("flight_cost_visualization.html")
# Out:
# /usr/local/lib/python3.10/dist-packages/plotly/graph_objs/_deprecations.py:143: DeprecationWarning:
#
# plotly.graph_objs.Annotation is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.Annotation
#   - plotly.graph_objs.layout.scene.Annotation
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="42b867e0-463e-4502-a3c3-1e04f6d82285" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("42b867e0-463e-4502-a3c3-1e04f6d82285")) {                    Plotly.newPlot(                        "42b867e0-463e-4502-a3c3-1e04f6d82285",                        [{"hoverinfo":"none","lat":[32.653829,28.0879],"line":{"color":"rgba(135, 180, 180, 0.8)","width":2},"locationmode":"USA-states","lon":[-83.189796,-82.4593],"mode":"lines","type":"scattergeo"},{"hoverinfo":"skip","lat":[32.653829],"locationmode":"USA-states","lon":[-83.189796],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Allentown","type":"scattergeo"},{"hoverinfo":"skip","lat":[28.0879],"locationmode":"USA-states","lon":[-82.4593],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Tampa","type":"scattergeo"},{"hoverinfo":"none","lat":[32.653829,37.208724],"line":{"color":"rgba(135, 180, 180, 0.8)","width":2},"locationmode":"USA-states","lon":[-83.189796,-105.928588],"mode":"lines","type":"scattergeo"},{"hoverinfo":"skip","lat":[37.208724],"locationmode":"USA-states","lon":[-105.928588],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Sanford","type":"scattergeo"},{"hoverinfo":"none","lat":[35.0936,33.916315],"line":{"color":"rgba(135, 180, 180, 0.8)","width":2},"locationmode":"USA-states","lon":[-106.6423,-84.827791],"mode":"lines","type":"scattergeo"},{"hoverinfo":"skip","lat":[35.0936],"locationmode":"USA-states","lon":[-106.6423],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Albuquerque","type":"scattergeo"},{"hoverinfo":"skip","lat":[33.916315],"locationmode":"USA-states","lon":[-84.827791],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Dallas","type":"scattergeo"},{"hoverinfo":"none","lat":[35.0936,39.840562],"line":{"color":"rgba(135, 180, 180, 0.8)","width":2},"locationmode":"USA-states","lon":[-106.6423,-105.007985],"mode":"lines","type":"scattergeo"},{"hoverinfo":"skip","lat":[39.840562],"locationmode":"USA-states","lon":[-105.007985],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Denver","type":"scattergeo"},{"hoverinfo":"none","lat":[35.0936,35.028369],"line":{"color":"rgba(135, 180, 180, 0.8)","width":2},"locationmode":"USA-states","lon":[-106.6423,-91.959398],"mode":"lines","type":"scattergeo"},{"hoverinfo":"skip","lat":[35.028369],"locationmode":"USA-states","lon":[-91.959398],"marker":{"color":"red","size":5},"mode":"markers+text","text":"Austin","type":"scattergeo"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888 ...

# %%
# df_merged[['LATITUDE1', 'LATITUDE2', 'LONGITUDE1', 'LONGITUDE2', 'fare', 'CITY1', 'CITY2']]

# %%
df_filtered = df_merged.dropna(subset=['LATITUDE1', 'LATITUDE2', 'LONGITUDE1', 'LONGITUDE2', 'fare', 'CITY1', 'CITY2'])
df_filtered=df_filtered.iloc[:20,:]

# %%
import plotly.graph_objs as go
import pandas as pd

# Assuming df_filtered is your DataFrame with the necessary columns

# Create the map figure
fig = go.Figure()

# Lists to store flight paths and city markers data
flight_paths_lons = []
flight_paths_lats = []
flight_paths_text = []
city_markers_lons = []
city_markers_lats = []
city_markers_text = []

# Set to keep track of plotted cities to ensure each city is only added once
plotted_cities = set()

# Populate lists for flight paths and city markers
for i, row in df_filtered.iterrows():
    # Flight path
    flight_paths_lons.extend([row['LONGITUDE1'], row['LONGITUDE2'], None])  # None to prevent line connecting to the next start
    flight_paths_lats.extend([row['LATITUDE1'], row['LATITUDE2'], None])
    flight_paths_text.append(f"{row['CITY1']} to {row['CITY2']} fare: ${row['fare']}")

    # Marker for CITY1
    if row['CITY1'] not in plotted_cities:
        city_markers_lons.append(row['LONGITUDE1'])
        city_markers_lats.append(row['LATITUDE1'])
        city_markers_text.append(f"{row['CITY1']}")
        plotted_cities.add(row['CITY1'])

    # Marker for CITY2
    if row['CITY2'] not in plotted_cities:
        city_markers_lons.append(row['LONGITUDE2'])
        city_markers_lats.append(row['LATITUDE2'])
        city_markers_text.append(f"{row['CITY2']}")
        plotted_cities.add(row['CITY2'])

# Add flight paths as a single trace
fig.add_trace(
    go.Scattergeo(
        locationmode='USA-states',
        lon=flight_paths_lons,
        lat=flight_paths_lats,
        mode='lines',
        line=dict(width=1, color='rgba(135, 206, 250, 0.5)'),
        opacity=0.4,
        text=flight_paths_text,
        hoverinfo='text'
    )
)

# Add city markers as a single trace
fig.add_trace(
    go.Scattergeo(
        locationmode='USA-states',
        lon=city_markers_lons,
        lat=city_markers_lats,
        text=city_markers_text,
        mode='markers+text',
        marker=dict(size=5, color='red'),
        hoverinfo='text'
    )
)

# Update the layout of the map
fig.update_layout(
    title_text='Flight Cost Visualization',
    showlegend=False,
    geo=dict(
        scope='usa',
        projection_type='albers usa',
        showland=True,
        landcolor='rgb(217, 217, 217)',
        subunitwidth=1,
        countrywidth=1,
        subunitcolor='rgb(255,255,255)',
        countrycolor='rgb(255,255,255)'
    ),
)

# Display the figure
fig.show()

# Alternatively, you can save the figure as an HTML file
fig.write_html("flight_cost_visualization.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6fc9bf12-1327-4813-9819-5ef95892b6e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6fc9bf12-1327-4813-9819-5ef95892b6e2")) {                    Plotly.newPlot(                        "6fc9bf12-1327-4813-9819-5ef95892b6e2",                        [{"hoverinfo":"text","lat":[32.653829,28.0879,null,32.653829,27.9428,null,32.653829,38.553437,null,40.158922,28.0879,null,40.158922,27.9428,null,40.158922,38.553437,null,42.083611,28.0879,null,42.083611,27.9428,null,42.083611,38.553437,null,40.602729,28.0879,null,40.602729,27.9428,null,40.602729,38.553437,null,32.653829,37.208724,null,32.653829,28.801307,null,32.653829,43.428541,null,32.653829,43.720352,null,32.653829,35.464148,null,32.653829,35.701944,null,32.653829,37.92433,null,40.158922,37.208724,null],"line":{"color":"rgba(135, 206, 250, 0.5)","width":1},"locationmode":"USA-states","lon":[-83.189796,-82.4593,null,-83.189796,-82.4549,null,-83.189796,-97.177388,null,-74.59093,-82.4593,null,-74.59093,-82.4549,null,-74.59093,-97.177388,null,-78.064722,-82.4593,null,-78.064722,-82.4549,null,-78.064722,-97.177388,null,-75.470955,-82.4593,null,-75.470955,-82.4549,null,-75.470955,-97.177388,null,-83.189796,-105.928588,null,-83.189796,-81.285044,null,-83.189796,-70.758479,null,-83.189796,-84.395446,null,-83.189796,-79.176446,null,-83.189796,-101.534167,null,-83.189796,-75.695704,null,-74.59093,-105.928588,null],"mode":"lines","opacity":0.4,"text":["Allentown to Tampa fare: $138.7","Allentown to Tampa fare: $138.7","Allentown to Tampa fare: $138.7","Allentown to Tampa fare: $138.7","Allentown to Tampa fare: $138.7","Allentown to Tampa fare: $138.7","Allentown to Tampa fare: $138.7","Allentown to Tampa fare: $138.7","Allentown to Tampa fare: $138.7","Allentown to Tampa fare: $138.7","Allentown to Tampa fare: $138.7","Allentown to Tampa fare: $138.7","Allentown to Sanford fare: $110.65","Allentown to Sanford fare: $110.65","Allentown to Sanford fare: $110.65","Allentown to Sanford fare: $110.65","Allentown to Sanford fare: $110.65","Allentown to Sanford fare: $110.65","Allentown to Sanford fare: $110.65","Allentown to Sanford fare: $110.65"],"type":"scattergeo"},{"hoverinfo":"text","lat":[32.653829,28.0879,37.208724],"locationmode":"USA-states","lon":[-83.189796,-82.4593,-105.928588],"marker":{"color":"red","size":5},"mode":"markers+text","text":["Allentown","Tampa","Sanford"],"type":"scattergeo"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinew ...
